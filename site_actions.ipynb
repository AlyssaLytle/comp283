# %% [markdown]
# ## Make a new site post

# %%
from site_utils import make_post

title = "Welcome!"

message = "Welcome to Comp283! I will be posting class updates here!"

make_post(title, message)
# Out:
# 2023-04-02 17:57:23.810581
